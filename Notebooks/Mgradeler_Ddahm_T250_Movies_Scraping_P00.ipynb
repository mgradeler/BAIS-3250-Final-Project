# %% [markdown]
# ### Melanie Gradeler
# ### Delanie Dahm
# ### BAIS:3025 Wrangling Scraping Project Code
# ### Michael Colbert
# ## <center><ins>Scraping Top 250 Movies and Details<ins><center>
# ### <p style="text-align: right">_November 12th, 2024_
# #### This file would be the first file to run in order, if starting this project from the begining
# **Purpose:** This project involves scraping movie data from IMDb's Top 250 movies list, including details like titles, ratings, runtimes, and additional information from individual movie pages. The scraped data will be scraped in subsequent steps. Two other jupyter notebooks will be used to clean and analyze the data. At the end of this notebook, there will be a total of three raw data files:
#
# 1.`top_250_raw.csv`
# 2.`top_250_details_raw.csv`

# %% [markdown]
# ### Initial Scraping Steps
# This section outlines the steps to scrape data from IMDb's Top 250 movies page. The focus is on extracting key details such as titles, release years, user ratings, runtimes, and URLs for further exploration.
#
# #### Importing Libraries
# The code below imports libraries required for web scraping and data handling
#
# **Purpose:** This block sets up the environment for scraping by loading the necessary tools and libraries.

# %%
import time #For adding delays during scraping to avoid overwhelming the server.
import pandas as pd #For organizing and analyzing the scraped data.
from selenium import webdriver #For automating browser actions and navigating the IMDb website.
from selenium.webdriver.common.by import By # used to import different ways to access data in the XML or HTML file
from selenium.webdriver.chrome.service import Service # no longer need to download a driver file, use service
from webdriver_manager.chrome import ChromeDriverManager # used to manage the Chrome driver to emulate a Chrome web browser

# %% [markdown]
# ### Setting Up WebDriver and Accessing IMDb
# **Purpose:** This block prepares the browser for scraping and specifies the target URL.

# %%
# Initialize Selenium WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# List to store scraped data
Top_250_movies_scraped_raw = []
#Directs the browser to the IMDb Top 250 Movies page and maximizes the window for better interaction.
url = f"https://www.imdb.com/chart/top/?ref_=nv_mv_250&sort=user_rating%2Cdesc"
driver.get(url)
driver.maximize_window()

# %% [markdown]
# ### Scraping Movie Details from IMBD
# This section focuses on scraping the following details from the IMDb Top 250 Movies page:
# 1. **Rank and Title**: Extracted from the main page.
# 2. **Year of Release**: Retrieved alongside the title.
# 3. **Rating**: User ratings for each movie.
# 4. **Runtime**: Duration of each movie.
# 5. **URL**: Link to the movie's detailed page for additional information.
#
# The extracted URLs are essential for scraping more detailed information in subsequent steps, which involve iterating through individual movie pages.
#
# This block also converts the raw scraped data into a second csv(`top_250_raw.csv`) and into a structured Pandas DataFrame and assigns column names for better readability.

# %%
## empty list for 250 movie details
top_250_scraped=[]
##initial summary element containing subsequent elements
movies_scraped = driver.find_elements(By.CLASS_NAME, 'ipc-metadata-list-summary-item')
#Loop though each movie in the initial list to find specific details such as year, runtime, rating and url
for movie in movies_scraped:
    
    # Scrape the movie title
    movie_title = movie.find_element(By.CLASS_NAME, 'ipc-title__text').text.strip()
    
    # Scrape the year if found to be blank then "N/A"
    try:
        year_element = movie.find_element(By.XPATH, ".//span[contains(@class, 'cli-title-metadata-item')][1]")
        movie_year = year_element.text.strip()
    except Exception:
        movie_year = "N/A"  # Handle cases where the year is not found

    # Scrape the runtime if found to be blank then "N/A"
    try:
        metadata_elements = movie.find_elements(By.XPATH, ".//span[contains(@class, 'cli-title-metadata-item')]")
        if len(metadata_elements) > 1:  # Assuming runtime is the second span
            movie_runtime = metadata_elements[1].text.strip()
        else:
            movie_runtime = "N/A"
    except Exception:
        movie_runtime = "N/A"  # Handle cases where the runtime is not found

    # Scrape the 2024 rating if found to be blank then "N/A"
    try:
        rating_element = movie.find_element(By.XPATH, ".//span[contains(@class, 'ipc-rating-star--rating')]")
        movie_rating = rating_element.text.strip()
    except Exception:
        movie_rating = "N/A"  # Handle cases where the rating is not found

    # Scrape the URL if found to be blank then "N/A"
    try:
        link_element = movie.find_element(By.XPATH, ".//a[@class='ipc-title-link-wrapper']")
        movie_url = link_element.get_attribute('href')
    except Exception:
        movie_url = "N/A"  # Handle cases where the link is not found

    #print(f"Title: {movie_title}, Year: {movie_year}, Runtime: {movie_runtime}, Rating: {movie_rating}, URL: {movie_url}")

#appending to empty list and making specific columns
    top_250_scraped.append({
            "title": movie_title,
            "year": movie_year,
            "run_time": movie_runtime,
            "IMBD_rating_2024": movie_rating,
            "url": movie_url
        })

#display(top_250_scraped)

# convert lists to a pandas datadataframe
print("Building the dataframe")
top_250_df = pd.DataFrame(top_250_scraped)

# # print data in a CSV file
print("Saving the CSV")
top_250_df.to_csv("top_250_raw.csv", header=True, index=False, sep=",", encoding='utf-8')
# Out:
# Building the dataframe
# Saving the CSV

# %% [markdown]
# ### Scraping Additional Deatails through each Individual Movie Pages
# This block:
# 1. Iterates through the URLs stored in the `top_250_details` DataFrame.
# 2. Visits each movie's page to scrape additional details such as:
#    - **Popularity Score, Metascore, and Number of Oscars**
#
# **Purpose:** Complements the initial data with more detailed information from individual movie pages.
# This block also converts the raw scraped data into a third csv (`top_250_details_raw.csv`) and into a structured Pandas DataFrame and assigns column names for better readability.

# %%
# List to store results
top_250_details = []

# Loop through the URLs in the DataFrame
for index, url in top_250_df['url'].dropna().items():
    try:
        # Visit the URL
        print(f"Visiting URL: {url}")
        driver.get(url)# Navigate to the URL
        time.sleep(5)  # Allow time for the page to load (adjust as needed)

        # Scrape the popularity score
        try:
            popularity_element = driver.find_element(By.XPATH, "//div[@data-testid='hero-rating-bar__popularity__score']")
            popularity_score = popularity_element.text.strip()
        except Exception:
            popularity_score = "N/A"  # Handle cases where the score is not found

        print(f"Popularity Score: {popularity_score}")

        # Scrape the meta score
        try:
            meta_element = driver.find_element(By.XPATH, "//span[contains(@class, 'metacritic-score-box')]")
            meta_score = meta_element.text.strip()
        except Exception:
            meta_score = "N/A"  # Handle cases where the score is not found

        print(f"Meta Score: {meta_score}")

        # Scrape the awards (filter later in cleaning file to include only oscars)
        try:
            award_element = driver.find_element(By.XPATH, "//a[contains(@class, 'ipc-metadata-list-item__label') and contains(@href, '/awards')]")
            award_text = award_element.text.strip()
        except Exception:
            award_text = "N/A"  # Handle cases where the score is not found

        print(f"Award: {award_text}")

        # Append results to the list
        top_250_details.append({'url': url, 'popularity_score': popularity_score, 'metascore': meta_score, 'oscars': award_text})

    except Exception as e:
        print(f"Error visiting {url}: {e}")

# Close the browser
#driver.quit()

# convert lists to a pandas datadataframe
print("building the dataframe")
top_250_details_df = pd.DataFrame(top_250_details)

# # perist data in a CSV file
print("saving the CSV")
top_250_details_df.to_csv("top_250_details_raw.csv", header=True, index=False, sep=",", encoding='utf-8')
# Out:
# Visiting URL: https://www.imdb.com/title/tt0111161/?ref_=chttp_t_1
# Popularity Score: 62
# Meta Score: 82
# Award: Nominated for 7 Oscars
# Visiting URL: https://www.imdb.com/title/tt0068646/?ref_=chttp_t_2
# Popularity Score: 57
# Meta Score: 100
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0468569/?ref_=chttp_t_3
# Popularity Score: 101
# Meta Score: 84
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0071562/?ref_=chttp_t_4
# Popularity Score: 185
# Meta Score: 90
# Award: Won 6 Oscars
# Visiting URL: https://www.imdb.com/title/tt0108052/?ref_=chttp_t_5
# Popularity Score: 211
# Meta Score: 95
# Award: Won 7 Oscars
# Visiting URL: https://www.imdb.com/title/tt0167260/?ref_=chttp_t_6
# Popularity Score: 233
# Meta Score: 94
# Award: Won 11 Oscars
# Visiting URL: https://www.imdb.com/title/tt0050083/?ref_=chttp_t_7
# Popularity Score: 254
# Meta Score: 97
# Award: Nominated for 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0120737/?ref_=chttp_t_8
# Popularity Score: 105
# Meta Score: 92
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0110912/?ref_=chttp_t_9
# Popularity Score: 137
# Meta Score: 95
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt1375666/?ref_=chttp_t_10
# Popularity Score: 126
# Meta Score: 74
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0137523/?ref_=chttp_t_11
# Popularity Score: 162
# Meta Score: 67
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0109830/?ref_=chttp_t_12
# Popularity Score: 208
# Meta Score: 82
# Award: Won 6 Oscars
# Visiting URL: https://www.imdb.com/title/tt0167261/?ref_=chttp_t_13
# Popularity Score: 386
# Meta Score: 87
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0060196/?ref_=chttp_t_14
# Popularity Score: 503
# Meta Score: 90
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt23849204/?ref_=chttp_t_15
# Popularity Score: 1,215
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0816692/?ref_=chttp_t_16
# Popularity Score: 33
# Meta Score: 74
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0099685/?ref_=chttp_t_17
# Popularity Score: 122
# Meta Score: 92
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0133093/?ref_=chttp_t_18
# Popularity Score: 235
# Meta Score: 73
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0073486/?ref_=chttp_t_19
# Popularity Score: 365
# Meta Score: 84
# Award: Won 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt0080684/?ref_=chttp_t_20
# Popularity Score: 954
# Meta Score: 82
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt15097216/?ref_=chttp_t_21
# Popularity Score: 2,834
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0114369/?ref_=chttp_t_22
# Popularity Score: 176
# Meta Score: 65
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0120815/?ref_=chttp_t_23
# Popularity Score: 181
# Meta Score: 91
# Award: Won 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt0120689/?ref_=chttp_t_24
# Popularity Score: 188
# Meta Score: 61
# Award: Nominated for 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0102926/?ref_=chttp_t_25
# Popularity Score: 191
# Meta Score: 86
# Award: Won 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt9362722/?ref_=chttp_t_26
# Popularity Score: 239
# Meta Score: 86
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0317248/?ref_=chttp_t_27
# Popularity Score: 294
# Meta Score: 79
# Award: Nominated for 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0103064/?ref_=chttp_t_28
# Popularity Score: 316
# Meta Score: 75
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0245429/?ref_=chttp_t_29
# Popularity Score: 388
# Meta Score: 96
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0038650/?ref_=chttp_t_30
# Popularity Score: 426
# Meta Score: 89
# Award: Nominated for 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt0076759/?ref_=chttp_t_31
# Popularity Score: 430
# Meta Score: 90
# Award: Won 6 Oscars
# Visiting URL: https://www.imdb.com/title/tt0118799/?ref_=chttp_t_32
# Popularity Score: 736
# Meta Score: 58
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0047478/?ref_=chttp_t_33
# Popularity Score: 1,239
# Meta Score: 98
# Award: Nominated for 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0056058/?ref_=chttp_t_34
# Popularity Score: 1,687
# Meta Score: 85
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0172495/?ref_=chttp_t_35
# Popularity Score: 8
# Meta Score: 67
# Award: Won 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt15239678/?ref_=chttp_t_36
# Popularity Score: 58
# Meta Score: 79
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0407887/?ref_=chttp_t_37
# Popularity Score: 186
# Meta Score: 85
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt1853728/?ref_=chttp_t_38
# Popularity Score: 189
# Meta Score: 81
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt6751668/?ref_=chttp_t_39
# Popularity Score: 195
# Meta Score: 97
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0110413/?ref_=chttp_t_40
# Popularity Score: 202
# Meta Score: 64
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0078748/?ref_=chttp_t_41
# Popularity Score: 207
# Meta Score: 89
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt2582802/?ref_=chttp_t_42
# Popularity Score: 222
# Meta Score: 89
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0088763/?ref_=chttp_t_43
# Popularity Score: 238
# Meta Score: 87
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0482571/?ref_=chttp_t_44
# Popularity Score: 250
# Meta Score: 66
# Award: Nominated for 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0110357/?ref_=chttp_t_45
# Popularity Score: 312
# Meta Score: 88
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0114814/?ref_=chttp_t_46
# Popularity Score: 418
# Meta Score: 76
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0120586/?ref_=chttp_t_47
# Popularity Score: 449
# Meta Score: 62
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0253474/?ref_=chttp_t_48
# Popularity Score: 626
# Meta Score: 85
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0054215/?ref_=chttp_t_49
# Popularity Score: 639
# Meta Score: 97
# Award: Nominated for 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0095327/?ref_=chttp_t_50
# Popularity Score: 710
# Meta Score: 94
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt1675434/?ref_=chttp_t_51
# Popularity Score: 723
# Meta Score: 57
# Award: Nominated for 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt0034583/?ref_=chttp_t_52
# Popularity Score: 739
# Meta Score: 100
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt26548265/?ref_=chttp_t_53
# Popularity Score: 826
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0064116/?ref_=chttp_t_54
# Popularity Score: 876
# Meta Score: 82
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0047396/?ref_=chttp_t_55
# Popularity Score: 1,040
# Meta Score: 100
# Award: Nominated for 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0095765/?ref_=chttp_t_56
# Popularity Score: 1,576
# Meta Score: 80
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0021749/?ref_=chttp_t_57
# Popularity Score: N/A
# Meta Score: 99
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0027977/?ref_=chttp_t_58
# Popularity Score: N/A
# Meta Score: 96
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0361748/?ref_=chttp_t_59
# Popularity Score: 116
# Meta Score: 69
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt7286456/?ref_=chttp_t_60
# Popularity Score: 157
# Meta Score: 59
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt1345836/?ref_=chttp_t_61
# Popularity Score: 178
# Meta Score: 78
# Award: Nominated for 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt4154796/?ref_=chttp_t_62
# Popularity Score: 243
# Meta Score: 78
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0081505/?ref_=chttp_t_63
# Popularity Score: 275
# Meta Score: 68
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0078788/?ref_=chttp_t_64
# Popularity Score: 369
# Meta Score: 94
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0090605/?ref_=chttp_t_65
# Popularity Score: 414
# Meta Score: 84
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0209144/?ref_=chttp_t_66
# Popularity Score: 425
# Meta Score: 83
# Award: Nominated for 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt2380307/?ref_=chttp_t_67
# Popularity Score: 439
# Meta Score: 81
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt4154756/?ref_=chttp_t_68
# Popularity Score: 457
# Meta Score: 68
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0082971/?ref_=chttp_t_69
# Popularity Score: 542
# Meta Score: 86
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0043014/?ref_=chttp_t_70
# Popularity Score: 558
# Meta Score: 94
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt5311514/?ref_=chttp_t_71
# Popularity Score: 587
# Meta Score: 81
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt4633694/?ref_=chttp_t_72
# Popularity Score: 641
# Meta Score: 87
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0405094/?ref_=chttp_t_73
# Popularity Score: 688
# Meta Score: 89
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0910970/?ref_=chttp_t_74
# Popularity Score: 750
# Meta Score: 95
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0086879/?ref_=chttp_t_75
# Popularity Score: 925
# Meta Score: 87
# Award: Won 8 Oscars
# Visiting URL: https://www.imdb.com/title/tt0050825/?ref_=chttp_t_76
# Popularity Score: 1,629
# Meta Score: 90
# Award: Nominated for 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt0082096/?ref_=chttp_t_77
# Popularity Score: 1,683
# Meta Score: 85
# Award: Nominated for 6 Oscars
# Visiting URL: https://www.imdb.com/title/tt8267604/?ref_=chttp_t_78
# Popularity Score: 1,732
# Meta Score: 75
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt1187043/?ref_=chttp_t_79
# Popularity Score: 2,295
# Meta Score: 67
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0051201/?ref_=chttp_t_80
# Popularity Score: 2,789
# Meta Score: 76
# Award: Nominated for 6 Oscars
# Visiting URL: https://www.imdb.com/title/tt0032553/?ref_=chttp_t_81
# Popularity Score: 4,250
# Meta Score: N/A
# Award: Nominated for 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt0057565/?ref_=chttp_t_82
# Popularity Score: 4,836
# Meta Score: 90
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt29623480/?ref_=chttp_t_83
# Popularity Score: 14
# Meta Score: 85
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt15398776/?ref_=chttp_t_84
# Popularity Score: 76
# Meta Score: 90
# Award: Won 7 Oscars
# Visiting URL: https://www.imdb.com/title/tt0119217/?ref_=chttp_t_85
# Popularity Score: 151
# Meta Score: 71
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0338013/?ref_=chttp_t_86
# Popularity Score: 179
# Meta Score: 89
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0180093/?ref_=chttp_t_87
# Popularity Score: 215
# Meta Score: 71
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0169547/?ref_=chttp_t_88
# Popularity Score: 236
# Meta Score: 84
# Award: Won 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt0113277/?ref_=chttp_t_89
# Popularity Score: 328
# Meta Score: 76
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0086250/?ref_=chttp_t_90
# Popularity Score: 335
# Meta Score: 65
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0364569/?ref_=chttp_t_91
# Popularity Score: 346
# Meta Score: 78
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0112573/?ref_=chttp_t_92
# Popularity Score: 351
# Meta Score: 68
# Award: Won 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt0091251/?ref_=chttp_t_93
# Popularity Score: 475
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0062622/?ref_=chttp_t_94
# Popularity Score: 515
# Meta Score: 84
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0087843/?ref_=chttp_t_95
# Popularity Score: 557
# Meta Score: 75
# Award: Won 2 BAFTA Awards
# Visiting URL: https://www.imdb.com/title/tt2106476/?ref_=chttp_t_96
# Popularity Score: 572
# Meta Score: 77
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt1255953/?ref_=chttp_t_97
# Popularity Score: 684
# Meta Score: 80
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0105236/?ref_=chttp_t_98
# Popularity Score: 702
# Meta Score: 81
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt8503618/?ref_=chttp_t_99
# Popularity Score: 729
# Meta Score: 88
# Award: Won 2 Primetime Emmys
# Visiting URL: https://www.imdb.com/title/tt0114709/?ref_=chttp_t_100
# Popularity Score: 751
# Meta Score: 96
# Award: Nominated for 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt1049413/?ref_=chttp_t_101
# Popularity Score: 785
# Meta Score: 88
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0211915/?ref_=chttp_t_102
# Popularity Score: 817
# Meta Score: 70
# Award: Nominated for 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt0057012/?ref_=chttp_t_103
# Popularity Score: 1,010
# Meta Score: 97
# Award: Nominated for 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0056172/?ref_=chttp_t_104
# Popularity Score: 1,161
# Meta Score: 100
# Award: Won 7 Oscars
# Visiting URL: https://www.imdb.com/title/tt0119698/?ref_=chttp_t_105
# Popularity Score: 1,307
# Meta Score: 76
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0086190/?ref_=chttp_t_106
# Popularity Score: 1,326
# Meta Score: 58
# Award: Nominated for 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0435761/?ref_=chttp_t_107
# Popularity Score: 1,365
# Meta Score: 92
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0053125/?ref_=chttp_t_108
# Popularity Score: 1,451
# Meta Score: 98
# Award: Nominated for 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0017136/?ref_=chttp_t_109
# Popularity Score: 1,518
# Meta Score: 98
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0056592/?ref_=chttp_t_110
# Popularity Score: 1,707
# Meta Score: 88
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0052357/?ref_=chttp_t_111
# Popularity Score: 1,820
# Meta Score: 100
# Award: Nominated for 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0033467/?ref_=chttp_t_112
# Popularity Score: 2,020
# Meta Score: 100
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0070735/?ref_=chttp_t_113
# Popularity Score: 2,263
# Meta Score: 83
# Award: Won 7 Oscars
# Visiting URL: https://www.imdb.com/title/tt0045152/?ref_=chttp_t_114
# Popularity Score: 2,511
# Meta Score: 99
# Award: Nominated for 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0053604/?ref_=chttp_t_115
# Popularity Score: 2,658
# Meta Score: 94
# Award: Won 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt0036775/?ref_=chttp_t_116
# Popularity Score: 2,917
# Meta Score: 95
# Award: Nominated for 7 Oscars
# Visiting URL: https://www.imdb.com/title/tt1832382/?ref_=chttp_t_117
# Popularity Score: 3,047
# Meta Score: 95
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt5074352/?ref_=chttp_t_118
# Popularity Score: 3,169
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0022100/?ref_=chttp_t_119
# Popularity Score: 3,184
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0044741/?ref_=chttp_t_120
# Popularity Score: 3,360
# Meta Score: 92
# Award: Nominated for 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt0055031/?ref_=chttp_t_121
# Popularity Score: 4,963
# Meta Score: 60
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0040522/?ref_=chttp_t_122
# Popularity Score: N/A
# Meta Score: N/A
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0986264/?ref_=chttp_t_123
# Popularity Score: N/A
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0993846/?ref_=chttp_t_124
# Popularity Score: 111
# Meta Score: 75
# Award: Nominated for 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt1745960/?ref_=chttp_t_125
# Popularity Score: 199
# Meta Score: 78
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0107290/?ref_=chttp_t_126
# Popularity Score: 230
# Meta Score: 68
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt10872600/?ref_=chttp_t_127
# Popularity Score: 245
# Meta Score: 71
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0372784/?ref_=chttp_t_128
# Popularity Score: 261
# Meta Score: 70
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0105695/?ref_=chttp_t_129
# Popularity Score: 263
# Meta Score: 85
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0477348/?ref_=chttp_t_130
# Popularity Score: 265
# Meta Score: 92
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0084787/?ref_=chttp_t_131
# Popularity Score: 281
# Meta Score: 57
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt1392214/?ref_=chttp_t_132
# Popularity Score: 282
# Meta Score: 70
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt1130884/?ref_=chttp_t_133
# Popularity Score: 289
# Meta Score: 63
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0095016/?ref_=chttp_t_134
# Popularity Score: 320
# Meta Score: 72
# Award: Nominated for 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0093058/?ref_=chttp_t_135
# Popularity Score: 358
# Meta Score: 78
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt8579674/?ref_=chttp_t_136
# Popularity Score: 398
# Meta Score: 78
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0120382/?ref_=chttp_t_137
# Popularity Score: 401
# Meta Score: 90
# Award: Nominated for 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0075314/?ref_=chttp_t_138
# Popularity Score: 402
# Meta Score: 94
# Award: Nominated for 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0167404/?ref_=chttp_t_139
# Popularity Score: 419
# Meta Score: 64
# Award: Nominated for 6 Oscars
# Visiting URL: https://www.imdb.com/title/tt6966692/?ref_=chttp_t_140
# Popularity Score: 437
# Meta Score: 69
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0066921/?ref_=chttp_t_141
# Popularity Score: 532
# Meta Score: 77
# Award: Nominated for 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0208092/?ref_=chttp_t_142
# Popularity Score: 568
# Meta Score: 55
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0469494/?ref_=chttp_t_143
# Popularity Score: 586
# Meta Score: 93
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0266697/?ref_=chttp_t_144
# Popularity Score: 611
# Meta Score: 69
# Award: Nominated for 5 BAFTA Awards
# Visiting URL: https://www.imdb.com/title/tt0457430/?ref_=chttp_t_145
# Popularity Score: 632
# Meta Score: 98
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0112641/?ref_=chttp_t_146
# Popularity Score: 673
# Meta Score: 73
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0268978/?ref_=chttp_t_147
# Popularity Score: 685
# Meta Score: 72
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0347149/?ref_=chttp_t_148
# Popularity Score: 774
# Meta Score: 82
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0057115/?ref_=chttp_t_149
# Popularity Score: 801
# Meta Score: 86
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0266543/?ref_=chttp_t_150
# Popularity Score: 805
# Meta Score: 90
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt4729430/?ref_=chttp_t_151
# Popularity Score: 827
# Meta Score: 65
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0119488/?ref_=chttp_t_152
# Popularity Score: 1,050
# Meta Score: 91
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0097576/?ref_=chttp_t_153
# Popularity Score: 1,085
# Meta Score: 65
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0363163/?ref_=chttp_t_154
# Popularity Score: 1,132
# Meta Score: 82
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0031381/?ref_=chttp_t_155
# Popularity Score: 1,343
# Meta Score: 97
# Award: Won 8 Oscars
# Visiting URL: https://www.imdb.com/title/tt1305806/?ref_=chttp_t_156
# Popularity Score: 1,498
# Meta Score: 80
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0071853/?ref_=chttp_t_157
# Popularity Score: 1,515
# Meta Score: 91
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt10272386/?ref_=chttp_t_158
# Popularity Score: 1,528
# Meta Score: 88
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0053291/?ref_=chttp_t_159
# Popularity Score: 1,750
# Meta Score: 98
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0080678/?ref_=chttp_t_160
# Popularity Score: 2,200
# Meta Score: 78
# Award: Nominated for 8 Oscars
# Visiting URL: https://www.imdb.com/title/tt0059578/?ref_=chttp_t_161
# Popularity Score: 2,404
# Meta Score: 74
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0042192/?ref_=chttp_t_162
# Popularity Score: 2,478
# Meta Score: 98
# Award: Won 6 Oscars
# Visiting URL: https://www.imdb.com/title/tt0089881/?ref_=chttp_t_163
# Popularity Score: 3,044
# Meta Score: 97
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0046912/?ref_=chttp_t_164
# Popularity Score: 4,002
# Meta Score: 75
# Award: Nominated for 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt0042876/?ref_=chttp_t_165
# Popularity Score: 4,483
# Meta Score: 98
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0055630/?ref_=chttp_t_166
# Popularity Score: N/A
# Meta Score: 93
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0040897/?ref_=chttp_t_167
# Popularity Score: N/A
# Meta Score: 98
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0118849/?ref_=chttp_t_168
# Popularity Score: N/A
# Meta Score: 77
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0049902/?ref_=chttp_t_169
# Popularity Score: N/A
# Meta Score: N/A
# Award: Nominated for 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt0012349/?ref_=chttp_t_170
# Popularity Score: N/A
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0476735/?ref_=chttp_t_171
# Popularity Score: N/A
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0015324/?ref_=chttp_t_172
# Popularity Score: N/A
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0032138/?ref_=chttp_t_173
# Popularity Score: 223
# Meta Score: 92
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0325980/?ref_=chttp_t_174
# Popularity Score: 276
# Meta Score: 63
# Award: Nominated for 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt0097165/?ref_=chttp_t_175
# Popularity Score: 297
# Meta Score: 79
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0091763/?ref_=chttp_t_176
# Popularity Score: 300
# Meta Score: 92
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt1392190/?ref_=chttp_t_177
# Popularity Score: 311
# Meta Score: 90
# Award: Won 6 Oscars
# Visiting URL: https://www.imdb.com/title/tt0434409/?ref_=chttp_t_178
# Popularity Score: 313
# Meta Score: 62
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt3315342/?ref_=chttp_t_179
# Popularity Score: 324
# Meta Score: 77
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt1201607/?ref_=chttp_t_180
# Popularity Score: 352
# Meta Score: 85
# Award: Nominated for 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0264464/?ref_=chttp_t_181
# Popularity Score: 359
# Meta Score: 75
# Award: Nominated for 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt2096673/?ref_=chttp_t_182
# Popularity Score: 364
# Meta Score: 94
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt2267998/?ref_=chttp_t_183
# Popularity Score: 378
# Meta Score: 79
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0088247/?ref_=chttp_t_184
# Popularity Score: 391
# Meta Score: 84
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0083658/?ref_=chttp_t_185
# Popularity Score: 409
# Meta Score: 84
# Award: Nominated for 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt2278388/?ref_=chttp_t_186
# Popularity Score: 442
# Meta Score: 88
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt4016934/?ref_=chttp_t_187
# Popularity Score: 446
# Meta Score: 85
# Award: Won 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt0382932/?ref_=chttp_t_188
# Popularity Score: 460
# Meta Score: 96
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt2119532/?ref_=chttp_t_189
# Popularity Score: 484
# Meta Score: 71
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0092005/?ref_=chttp_t_190
# Popularity Score: 501
# Meta Score: 75
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt1454029/?ref_=chttp_t_191
# Popularity Score: 508
# Meta Score: 62
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0118715/?ref_=chttp_t_192
# Popularity Score: 530
# Meta Score: 71
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0073195/?ref_=chttp_t_193
# Popularity Score: 553
# Meta Score: 87
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0070047/?ref_=chttp_t_194
# Popularity Score: 643
# Meta Score: 83
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0117951/?ref_=chttp_t_195
# Popularity Score: 718
# Meta Score: 83
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0892769/?ref_=chttp_t_196
# Popularity Score: 725
# Meta Score: 75
# Award: Nominated for 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt1950186/?ref_=chttp_t_197
# Popularity Score: 763
# Meta Score: 81
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0353969/?ref_=chttp_t_198
# Popularity Score: 767
# Meta Score: 82
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0116282/?ref_=chttp_t_199
# Popularity Score: 784
# Meta Score: 88
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0059742/?ref_=chttp_t_200
# Popularity Score: 794
# Meta Score: 63
# Award: Won 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt0077416/?ref_=chttp_t_201
# Popularity Score: 873
# Meta Score: 90
# Award: Won 5 Oscars
# Visiting URL: https://www.imdb.com/title/tt0075148/?ref_=chttp_t_202
# Popularity Score: 882
# Meta Score: 70
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt1291584/?ref_=chttp_t_203
# Popularity Score: 887
# Meta Score: 71
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0758758/?ref_=chttp_t_204
# Popularity Score: 929
# Meta Score: 73
# Award: Nominated for 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0198781/?ref_=chttp_t_205
# Popularity Score: 1,011
# Meta Score: 79
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt2024544/?ref_=chttp_t_206
# Popularity Score: 1,016
# Meta Score: 96
# Award: Won 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0405159/?ref_=chttp_t_207
# Popularity Score: 1,028
# Meta Score: 86
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0087884/?ref_=chttp_t_208
# Popularity Score: 1,044
# Meta Score: 81
# Award: Won 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt5027774/?ref_=chttp_t_209
# Popularity Score: 1,052
# Meta Score: 88
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt1895587/?ref_=chttp_t_210
# Popularity Score: 1,167
# Meta Score: 93
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt1979320/?ref_=chttp_t_211
# Popularity Score: 1,253
# Meta Score: 74
# Award: Won 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt0112471/?ref_=chttp_t_212
# Popularity Score: 1,274
# Meta Score: 78
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0036868/?ref_=chttp_t_213
# Popularity Score: 1,304
# Meta Score: 93
# Award: Won 7 Oscars
# Visiting URL: https://www.imdb.com/title/tt0120735/?ref_=chttp_t_214
# Popularity Score: 1,411
# Meta Score: 67
# Award: Won 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt0071315/?ref_=chttp_t_215
# Popularity Score: 1,427
# Meta Score: 92
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt3170832/?ref_=chttp_t_216
# Popularity Score: 1,676
# Meta Score: 86
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0072684/?ref_=chttp_t_217
# Popularity Score: 1,706
# Meta Score: 89
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt1205489/?ref_=chttp_t_218
# Popularity Score: 1,763
# Meta Score: 73
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt3011894/?ref_=chttp_t_219
# Popularity Score: 1,771
# Meta Score: 77
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0096283/?ref_=chttp_t_220
# Popularity Score: 1,870
# Meta Score: 87
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt5323662/?ref_=chttp_t_221
# Popularity Score: 1,898
# Meta Score: 78
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0081398/?ref_=chttp_t_222
# Popularity Score: 2,029
# Meta Score: 90
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0113247/?ref_=chttp_t_223
# Popularity Score: 2,086
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0129167/?ref_=chttp_t_224
# Popularity Score: 2,148
# Meta Score: 85
# Award: Won 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt1028532/?ref_=chttp_t_225
# Popularity Score: 2,235
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0050212/?ref_=chttp_t_226
# Popularity Score: 2,287
# Meta Score: 88
# Award: Won 7 Oscars
# Visiting URL: https://www.imdb.com/title/tt0052618/?ref_=chttp_t_227
# Popularity Score: 2,354
# Meta Score: 90
# Award: Won 11 Oscars
# Visiting URL: https://www.imdb.com/title/tt0041959/?ref_=chttp_t_228
# Popularity Score: 2,366
# Meta Score: 97
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0074958/?ref_=chttp_t_229
# Popularity Score: 2,517
# Meta Score: 83
# Award: Won 4 Oscars
# Visiting URL: https://www.imdb.com/title/tt0978762/?ref_=chttp_t_230
# Popularity Score: 2,625
# Meta Score: 72
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0381681/?ref_=chttp_t_231
# Popularity Score: 2,681
# Meta Score: 91
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0032976/?ref_=chttp_t_232
# Popularity Score: 2,738
# Meta Score: 86
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0050976/?ref_=chttp_t_233
# Popularity Score: 2,804
# Meta Score: 88
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0107207/?ref_=chttp_t_234
# Popularity Score: 2,806
# Meta Score: 84
# Award: Nominated for 7 Oscars
# Visiting URL: https://www.imdb.com/title/tt0047296/?ref_=chttp_t_235
# Popularity Score: 3,204
# Meta Score: 91
# Award: Won 8 Oscars
# Visiting URL: https://www.imdb.com/title/tt0395169/?ref_=chttp_t_236
# Popularity Score: 3,983
# Meta Score: 79
# Award: Nominated for 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0032551/?ref_=chttp_t_237
# Popularity Score: N/A
# Meta Score: 96
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0046268/?ref_=chttp_t_238
# Popularity Score: N/A
# Meta Score: 85
# Award: Won 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt0058946/?ref_=chttp_t_239
# Popularity Score: N/A
# Meta Score: 96
# Award: Nominated for 3 Oscars
# Visiting URL: https://www.imdb.com/title/tt0050986/?ref_=chttp_t_240
# Popularity Score: N/A
# Meta Score: 88
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0046438/?ref_=chttp_t_241
# Popularity Score: N/A
# Meta Score: 100
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0031679/?ref_=chttp_t_242
# Popularity Score: N/A
# Meta Score: 73
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0019254/?ref_=chttp_t_243
# Popularity Score: N/A
# Meta Score: 98
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0035446/?ref_=chttp_t_244
# Popularity Score: N/A
# Meta Score: 86
# Award: Nominated for 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0015864/?ref_=chttp_t_245
# Popularity Score: N/A
# Meta Score: N/A
# Award: Nominated for 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0017925/?ref_=chttp_t_246
# Popularity Score: N/A
# Meta Score: N/A
# Award: Awards
# Visiting URL: https://www.imdb.com/title/tt0317705/?ref_=chttp_t_247
# Popularity Score: 580
# Meta Score: 90
# Award: Won 2 Oscars
# Visiting URL: https://www.imdb.com/title/tt0107048/?ref_=chttp_t_248
# Popularity Score: 1,293
# Meta Score: 72
# Award: Won 1 BAFTA Award
# Visiting URL: https://www.imdb.com/title/tt0061512/?ref_=chttp_t_249
# Popularity Score: 2,748
# Meta Score: 92
# Award: Won 1 Oscar
# Visiting URL: https://www.imdb.com/title/tt0245712/?ref_=chttp_t_250
# Popularity Score: 3,119
# Meta Score: 83
# Award: Nominated for 1 Oscar
# building the dataframe
# saving the CSV
